# %% [markdown]
# <a href="https://colab.research.google.com/github/Nemesis313/Debian-Pi-Aarch64/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install dydx-v3-python==1.9.1
# !pip3 install web3==5.31.3
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.1/109.1 KB 3.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 9.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.3/103.3 KB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.6/231.6 KB 11.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.8/101.8 KB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 279.9/279.9 KB 19.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 502.8/502.8 KB 27.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 50.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 481.0/481.0 KB 24.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 511.4/511.4 KB 21.0 MB/s eta 0:00:00
# ...

# %%
# Imports
from dydx3 import Client
from web3 import Web3
from pprint import pprint
from datetime import datetime, timedelta

# Use for Testnet
from dydx3.constants import API_HOST_GOERLI

# # Use for Mainnet
from dydx3.constants import API_HOST_MAINNET

# %%
# Contracts
ETHEREUM_ADDRESS = "0x11f532C2c63f3d4f2E432Ad8cfE2691E14797c76"
ETH_PRIVATE_KEY = "0xbf716ce781fe9850b9d9092574ead7b88a538a7aa5a002ea711982152415f2f2"

STARK_PRIVATE_KEY = "05f1c5a66c39cceda76dd2fae100c2d2b2d85939cb6e0bbb4af51fbdc9f79237"
DYDX_API_KEY = "ed96f016-8bed-5f66-ac78-2e6dcc710574" 
DYDX_API_SECRET = "_yeGm7-41NO13EEZ6wQYqhwxBv7EJPlgyuRjxUbv"
DYDX_API_PASSPHRASE = "xh8F9gVpSmW1kNnsEJfS"
HOST = API_HOST_GOERLI

# %%
# Create Client Connection
client=Client(
    host=Host,
    api_key_credentials=Host,
    host=Host,
    host=Host  
)
